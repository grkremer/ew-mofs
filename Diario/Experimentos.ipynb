# %% [markdown]
# ### Diario de experimentos

# %% [markdown]
# Experimento 1:
# 5 fold crossover
# 5 runs por experimento
# 5 reproduções
# 200 individuos
# 500 gerações
# Com e sem método proposto
# Em vermelho sem a técnica
# Em azul com a técnica
# Medias de
# 0.9806256648360518
# 0.9804294029449293
#
# Observações: Usei 24 threads, demorou muito!
#
# Conclusão: Não notou-se diferença

# %% [markdown]
# ![image.png](attachment:fa1e4cf9-8899-43a2-8bc0-1e6d6c1e62ad.png)

# %% [markdown]
# Experimento 1:
# 5 fold crossover
# 5 runs por experimento
# 5 reproduções
# 200 individuos
# ***250 gerações
# Com e sem método proposto
# Em vermelho sem a técnica
# Em azul com a técnica
# Medias de
# 0.9789714298472774
# 0.9786065254637932
#
# Observações: Usei484 threads,corrigi um bug no multiprocessing, rodou em umas 4 horas!
#
# Conclusão: Não notou-se diferenç
# Mas agora roda muuuito mais rápidoa

# %% [markdown]
# ![download.png](attachment:3b2cb300-527b-4afb-9a1e-6d3f5013ffd9.png)

# %% [markdown]
# Experimento 3:
# Alguma coisa deu errado

# %% [markdown]
# ![download 4.png](attachment:2ad075b9-413f-421c-b63f-5d33ae173a56.png)

# %% [markdown]
# Experimento 4:
# 5 fold crossover
# 5 runs por experimento
# 5 reproduções
# *500 individuos
# *250 gerações
# Com e sem método proposto
# Em vermelho sem a técnica
# Em azul com a técnica
# Medias de
# 0.08805562269116445
# 0.08901553963754424
#
# Notei que possivelmente o metodo de calculo do hypervolume estava levando a conclusões precipitadas
# Alterei o ponto de referencia pra esse calculo, observou-se 1% de diferença entre o algoritmo modificado e o original
# Essa diferença é mais visivel observando a curva de pareto, é possível que as soluções sejam melhores

# %% [markdown]
# ![download 5.png](attachment:05a7063c-1667-4290-8014-5ffbae83f279.png)![download 6.png](attachment:f166c18f-8fe4-4c36-84a1-3b04e7f295b2.png)

# %%
Experimento 5:
Inicialização com FILTER
5 fold crossover
5 runs por experimento
5 reproduções
*100 individuos
*200 gerações
Com e sem método proposto
Em vermelho sem a técnica
Em azul com a técnica
Medias de 
0.08427324848623607
0.08423695004368813

# %% [markdown]
# ![download.png](attachment:edbc7301-7ae8-4490-a0e6-381ab388dc3b.png)

# %%
Experimento 5:
Inicialização SEM FILTER
5 fold crossover
5 runs por experimento
5 reproduções
*400 individuos
*200 gerações
Com e sem método proposto
Em vermelho sem a técnica
Em azul com a técnica
Medias de 
0.08575179686821324
0.08566201686586357

# %% [markdown]
# ![download.png](attachment:e9bb3bc4-9551-44b3-b834-dd08188212dd.png)

# %%
Experimento 6:
Inicialização SEM FILTER
Agora com lógica FUZZY
5 fold crossover
5 runs por experimento
5 reproduções
*400 individuos
*200 gerações
Com e sem método proposto
Em vermelho sem a técnica
Em azul com a técnica
Medias de 
0.08833571800158484
0.08783466218238664

# %% [markdown]
# ![download.png](attachment:f6931c81-fbba-438d-9297-9d8fa72968fe.png)

# %%
Experimento 7:
Inicialização SEM FILTER
Agora com lógica FUZZY
COM METODO NA EXECUÇÃO TODA
5 fold crossover
5 runs por experimento
5 reproduções
*100 individuos
*200 gerações
Com e sem método proposto
Em vermelho sem a técnica
Em azul com a técnica
Medias de 
0.8682514747900967
0.8701799076977093

# %% [markdown]
# ![download 8.png](attachment:88fee598-a4ec-4cff-bc0f-84d9ee780d3e.png)
# ![download 9.png](attachment:572a1250-e351-42c6-bd10-fe2303082de8.png)

# %%
Experimento 8:
Inicialização SEM FILTER
Agora com lógica FUZZY
COM METODO NA EXECUÇÃO TODA
INVERTIDA A POLITICA DE EXPLORAÇÃO (BENEFICIA ONTOLOGIAS DIVERSAS)
5 fold crossover
5 runs por experimento
5 reproduções
*100 individuos
*200 gerações
Com e sem método proposto
Em vermelho sem a técnica
Em azul com a técnica
Medias de 
0.8226385574937426
0.8336310595987839

# %% [markdown]
# ![download 11.png](attachment:bddc17a3-6e61-4f79-ad54-c552f136d47a.png)![download 12.png](attachment:59931c94-56b9-4855-919b-8a58de04475e.png)![download 13.png](attachment:ea1dac0c-5198-446c-8412-5f7ae70c1d43.png)

# %%
#########################################333

# %%
Nova técnica, agora utilizando os dados dos pathways como heuristica

200 gerações
Lógica fuzzy + 0.5 de compensação
5 execuções
10 folds
0.8337599999999996
0.8091599999999997

# %% [markdown]
# ![download 14.png](attachment:e2e7fad7-dbd5-4ad2-a2cf-4b7531d3fd3b.png)

# %%
Novo metodo de sampling
Com e sem considerar pontuação dos pathways para gerar a população inicial

# %%
Após rodar um grande experimento com população inicial de 300
e 400 gerações, o leo me sugeriu que o algoritmo não estava
convergindo corretamente.
Mean:  0.8573799999999997
STD:  0.021578498557592023
Mean:  0.8427799999999998
STD:  0.026452818375364093

# %% [markdown]
# ![download.png](attachment:077975cc-445f-40b9-9c0b-dd2d4fa13327.png)![download.png](attachment:d3276628-eaaa-45da-8ee7-fa7958ccaf20.png)

# %%
Seguindo a sugestão do leo de rodar mais gerações com menos individuos
mesma coisa de antes
50 individuos
1000 gerações
Mean:  0.7997499999999996
STD:  0.029341225264122802
Mean:  0.8006999999999996
STD:  0.039474168768955764

# %% [markdown]
# ![download.png](attachment:969a68d9-1bfd-4ca8-9d7f-5b98e8c30317.png)![download 2.png](attachment:0f6f3eb5-f36c-42e7-b08c-5b100ee50d92.png)
